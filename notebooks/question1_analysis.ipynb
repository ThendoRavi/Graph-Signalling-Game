# %% [markdown]
# # Question 1 Analysis
#
# Convention characterisation on K_{2,2} (Section 4.6).
# Load run outputs from `results/question1/` and produce tables/figures:
# convergence rate, mean team reward, mutual information, channel utilisation,
# joint convention distribution, complementarity rate, convention entropy,
# and the cross-play gap.
